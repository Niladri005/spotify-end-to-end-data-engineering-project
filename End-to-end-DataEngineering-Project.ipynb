# %%
# !pip install spotipy
# Out:
# ...
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="d3a0aadcba0d44a5a53693dbd99f86b0",
                                                           client_secret="ea7b125208be4622b4caaa6c56c6e382"))

# %%
# top 100 Global playlist in Spotify
playlist='https://open.spotify.com/playlist/5dnSFdz51E2Qouk7iFnwbl'

# %%
playlist_uri= playlist.split('/')[-1]

# %%
playlist_uri
# Out:
# '5dnSFdz51E2Qouk7iFnwbl'

# %%
data=sp.playlist_tracks(playlist_uri)

# %%
##Extract Album Information

# %%
# Printing track names
for idx, item in enumerate(data['items']):
    track=item['track']
    print(f"{idx+1}. {track['name']} by {track['artists'][0]['name']}")
# Out:
# 1. What Did I Miss? by Drake
# 2. What I Want (feat. Tate McRae) by Morgan Wallen
# 3. Ordinary by Alex Warren
# 4. Courtesy Of The Red, White And Blue (The Angry American) by Toby Keith
# 5. Just In Case by Morgan Wallen
# 6. I Had Some Help (Feat. Morgan Wallen) by Post Malone
# 7. I'm The Problem by Morgan Wallen
# 8. A Bar Song (Tipsy) by Shaboozey
# 9. luther (with sza) by Kendrick Lamar
# 10. APT. by ROSÉ
# 11. Manchild by Sabrina Carpenter
# 12. Die With A Smile by Lady Gaga
# 13. Not Like Us by Kendrick Lamar
# 14. Golden by HUNTR/X
# 15. NOKIA by Drake
# 16. Just Keep Watching by Tate McRae
# 17. BIRDS OF A FEATHER by Billie Eilish
# 18. Burning Blue by Mariah the Scientist
# 19. Outside by Cardi B
# 20. Superman by Morgan Wallen
# 21. I Got Better by Morgan Wallen
# 22. 20 Cigarettes by Morgan Wallen
# 23. 30 For 30 (with Kendrick Lamar) by SZA
# 24. ライラック by Mrs. GREEN APPLE
# 25. Love Somebody by Morgan Wallen
# 26. Pink Pony Club by Chappell Roan
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2025-07-06T10:08:50Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/suo2sbl91eeth3elwrfuq7qwn'},
#   'href': 'https://api.spotify.com/v1/users/suo2sbl91eeth3elwrfuq7qwn',
#   'id': 'suo2sbl91eeth3elwrfuq7qwn',
#   'type': 'user',
#   'uri': 'spotify:user:suo2sbl91eeth3elwrfuq7qwn'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
data['items'][0]['track']['name']
# Out:
# 'What Did I Miss?'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-07-05'

# %%
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Drake'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/0bNfrGST1xSPZ3V3g5jjHT'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0bNfrGST1xSPZ3V3g5jjHT'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['album_type']
# Out:
# 'single'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_release_date= row['track']['album']['release_date']
    album_track_name=row['track']['name']
    artist_name=row['track']['artists'][0]['name']
    total_tracks= row['track']['album']['total_tracks']
    album_type=row['track']['album']['album_type']
    
    album_elements = {
    'album_id': album_id,
    'release_date': album_release_date,
    'track_name': album_track_name,
    'artist_name': artist_name,
    'total_tracks': total_tracks,
    'album_type': album_type
    }
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '0bNfrGST1xSPZ3V3g5jjHT',
#   'release_date': '2025-07-05',
#   'track_name': 'What Did I Miss?',
#   'artist_name': 'Drake',
#   'total_tracks': 1,
#   'album_type': 'single'},
#  {'album_id': '1o844O5I0qVpZKiePtIGcF',
#   'release_date': '2025-05-16',
#   'track_name': 'What I Want (feat. Tate McRae)',
#   'artist_name': 'Morgan Wallen',
#   'total_tracks': 37,
#   'album_type': 'album'},
#  {'album_id': '6xomx5ekO7qHDvDh57rZ5S',
#   'release_date': '2025-02-07',
#   'track_name': 'Ordinary',
#   'artist_name': 'Alex Warren',
#   'total_tracks': 1,
#   'album_type': 'single'},
#  {'album_id': '7ExectJocqn8sMKq4Tn4LY',
#   'release_date': '2002-01-01',
#   'track_name': 'Courtesy Of The Red, White And Blue (The Angry American)',
#   'artist_name': 'Toby Keith',
#   'total_tracks': 13,
#   'album_type': 'album'},
#  {'album_id': '1o844O5I0qVpZKiePtIGcF',
#   'release_date': '2025-05-16',
#   'track_name': 'Just In Case',
#   'artist_name': 'Morgan Wallen',
# ...

# %% [markdown]
# ##Extract Artist Information

# %%
data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#   'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#   'id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'name': 'Morgan Wallen',
#   'type': 'artist',
#   'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#   'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#   'id': '45dkTj5sMRSjrmBSBeiHym',
#   'name': 'Tate McRae',
#   'type': 'artist',
#   'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}]

# %%
artist_list=[]

for row in data['items']:
    for key, value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '0fTSzq9jAh4c36UVb4V7CB',
#   'artist_name': 'Alex Warren',
#   'external_url': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB'},
#  {'artist_id': '2bA6fzP0lMAQ4kz6CF61w8',
#   'artist_name': 'Toby Keith',
#   'external_url': 'https://api.spotify.com/v1/artists/2bA6fzP0lMAQ4kz6CF61w8'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
# ...

# %%
##Song information

# %%
data['items'][0]['track']['name']
# Out:
# 'What Did I Miss?'

# %%
data['items'][0]['track']['id']
# Out:
# '57GsLpRtEtrzcPGPop20rS'

# %%
data['items'][0]['track']['duration_ms']
# Out:
# 194324

# %%
data['items'][0]['track']['popularity']
# Out:
# 0

# %%
#now I will extract all the information in the same way

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '57GsLpRtEtrzcPGPop20rS',
#   'song_name': 'What Did I Miss?',
#   'duration_ms': 194324,
#   'url': 'https://open.spotify.com/track/57GsLpRtEtrzcPGPop20rS',
#   'popularity': 0,
#   'song_added': '2025-07-06T10:08:50Z',
#   'album_id': '0bNfrGST1xSPZ3V3g5jjHT',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4'},
#  {'song_id': '48NthgcgfoRrWT8LtgW28A',
#   'song_name': 'What I Want (feat. Tate McRae)',
#   'duration_ms': 184517,
#   'url': 'https://open.spotify.com/track/48NthgcgfoRrWT8LtgW28A',
#   'popularity': 76,
#   'song_added': '2025-07-06T10:08:50Z',
#   'album_id': '1o844O5I0qVpZKiePtIGcF',
#   'artist_id': '4oUHIQIBe0LHzYfvXNW4QM'},
#  {'song_id': '6qqrTXSdwiJaq8SO0X2lSe',
#   'song_name': 'Ordinary',
#   'duration_ms': 186964,
#   'url': 'https://open.spotify.com/track/6qqrTXSdwiJaq8SO0X2lSe',
#   'popularity': 97,
#   'song_added': '2025-07-06T10:08:50Z',
#   'album_id': '6xomx5ekO7qHDvDh57rZ5S',
#   'artist_id': '0fTSzq9jAh4c36UVb4V7CB'},
# ...

# %%
#Going to be interesting now
#I will create a pd dataframe using the lists that I have just created.

# %%
import pandas as pd

album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df #This is Cool---
# Out:
#                   album_id release_date  \
# 0   0bNfrGST1xSPZ3V3g5jjHT   2025-07-05
# 1   1o844O5I0qVpZKiePtIGcF   2025-05-16
# 2   6xomx5ekO7qHDvDh57rZ5S   2025-02-07
# 3   7ExectJocqn8sMKq4Tn4LY   2002-01-01
# 4   1o844O5I0qVpZKiePtIGcF   2025-05-16
# ..                     ...          ...
# 95  3uTpTaMOynCYKV5AtgeO2U   2024-06-21
# 96  14JkAa6IiFaOh5s0nMyMU9   2025-06-20
# 97  7LRZfujsTLyy814AnMSdtT   2024-05-24
# 98  5uNvYxV3OV1b0BGlClvujb   2022-11-07
# 99  0hvT3yIEysuuvkK73vgdcW   2024-11-22
#
#                                            track_name       artist_name  \
# 0                                    What Did I Miss?             Drake
# 1                      What I Want (feat. Tate McRae)     Morgan Wallen
# 2                                            Ordinary       Alex Warren
# 3   Courtesy Of The Red, White And Blue (The Angry...        Toby Keith
# 4                                        Just In Case     Morgan Wallen
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   release_date  100 non-null    object
#  2   track_name    100 non-null    object
#  3   artist_name   100 non-null    object
#  4   total_tracks  100 non-null    int64
#  5   album_type    100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
album_df= album_df.drop_duplicates(subset='album_id')

# %%
#release_date  need to be converted to Datatime
album_df['release_date']= pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\goswa\AppData\Local\Temp\ipykernel_11336\1368662473.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date']= pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      78 non-null     object
#  1   release_date  78 non-null     datetime64[ns]
#  2   track_name    78 non-null     object
#  3   artist_name   78 non-null     object
#  4   total_tracks  78 non-null     int64
#  5   album_type    78 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 4.3+ KB

# %%
#now I will convert artist_list to Dataframe

artist_df= pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                   artist_id              artist_name  \
# 0    3TVXtAsR1Inumwj472S9r4                    Drake
# 1    4oUHIQIBe0LHzYfvXNW4QM            Morgan Wallen
# 2    45dkTj5sMRSjrmBSBeiHym               Tate McRae
# 3    0fTSzq9jAh4c36UVb4V7CB              Alex Warren
# 4    2bA6fzP0lMAQ4kz6CF61w8               Toby Keith
# ..                      ...                      ...
# 150  7mW7Tv7NvywKKXqafZo0Lc  KPop Demon Hunters Cast
# 151  40ZNYROS4zLfyyBSs2PGe2               Zach Bryan
# 152  4QvgGvpgzgyUOo8Yp8LDm9         Mrs. GREEN APPLE
# 153  2YZyLoL8N0Wb9xBt1NhZWg           Kendrick Lamar
# 154  1jiZvw42D4oquLl24x2VWV            Lefty Gunplay
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/3TVXtAsR1In...
# 1    https://api.spotify.com/v1/artists/4oUHIQIBe0L...
# 2    https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 3    https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# ...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     155 non-null    object
#  1   artist_name   155 non-null    object
#  2   external_url  155 non-null    object
# dtypes: object(3)
# memory usage: 3.8+ KB

# %%
artist_df
# Out:
#                   artist_id        artist_name  \
# 0    3TVXtAsR1Inumwj472S9r4              Drake
# 1    4oUHIQIBe0LHzYfvXNW4QM      Morgan Wallen
# 2    45dkTj5sMRSjrmBSBeiHym         Tate McRae
# 3    0fTSzq9jAh4c36UVb4V7CB        Alex Warren
# 4    2bA6fzP0lMAQ4kz6CF61w8         Toby Keith
# ..                      ...                ...
# 142  0Y5tJX1MQlPlqiwlOH1tJY       Travis Scott
# 143  3eqjTLE0HfPfh78zjh6TqT  Bruce Springsteen
# 145  67FB4n52MgexGQIG8s0yUH         Lola Young
# 151  40ZNYROS4zLfyyBSs2PGe2         Zach Bryan
# 154  1jiZvw42D4oquLl24x2VWV      Lefty Gunplay
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/3TVXtAsR1In...
# 1    https://api.spotify.com/v1/artists/4oUHIQIBe0L...
# 2    https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 3    https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 4    https://api.spotify.com/v1/artists/2bA6fzP0lMA...
# ..                                                 ...
# ...

# %%
#Delete Dups

artist_df= artist_df.drop_duplicates(subset='artist_id')

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  3TVXtAsR1Inumwj472S9r4          Drake
# 1  4oUHIQIBe0LHzYfvXNW4QM  Morgan Wallen
# 2  45dkTj5sMRSjrmBSBeiHym     Tate McRae
# 3  0fTSzq9jAh4c36UVb4V7CB    Alex Warren
# 4  2bA6fzP0lMAQ4kz6CF61w8     Toby Keith
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/3TVXtAsR1In...
# 1  https://api.spotify.com/v1/artists/4oUHIQIBe0L...
# 2  https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 3  https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 4  https://api.spotify.com/v1/artists/2bA6fzP0lMA...

# %%
artist_df
# Out:
#                   artist_id        artist_name  \
# 0    3TVXtAsR1Inumwj472S9r4              Drake
# 1    4oUHIQIBe0LHzYfvXNW4QM      Morgan Wallen
# 2    45dkTj5sMRSjrmBSBeiHym         Tate McRae
# 3    0fTSzq9jAh4c36UVb4V7CB        Alex Warren
# 4    2bA6fzP0lMAQ4kz6CF61w8         Toby Keith
# ..                      ...                ...
# 142  0Y5tJX1MQlPlqiwlOH1tJY       Travis Scott
# 143  3eqjTLE0HfPfh78zjh6TqT  Bruce Springsteen
# 145  67FB4n52MgexGQIG8s0yUH         Lola Young
# 151  40ZNYROS4zLfyyBSs2PGe2         Zach Bryan
# 154  1jiZvw42D4oquLl24x2VWV      Lefty Gunplay
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/3TVXtAsR1In...
# 1    https://api.spotify.com/v1/artists/4oUHIQIBe0L...
# 2    https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 3    https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 4    https://api.spotify.com/v1/artists/2bA6fzP0lMA...
# ..                                                 ...
# ...

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   57GsLpRtEtrzcPGPop20rS                                   What Did I Miss?
# 1   48NthgcgfoRrWT8LtgW28A                     What I Want (feat. Tate McRae)
# 2   6qqrTXSdwiJaq8SO0X2lSe                                           Ordinary
# 3   0M7mWKqwTIaVjYyxfZmtTa  Courtesy Of The Red, White And Blue (The Angry...
# 4   47i9UVf2GnGcOgT51RXEw3                                       Just In Case
# ..                     ...                                                ...
# 95  35ISBknsCeZQtq66xABI9g                                              Messy
# 96  0MHStU0muAIEMbwdnebYu2                                           Takedown
# 97  4ZJ4vzLQekI0WntDbanNC7                                         Pink Skies
# 98  7qXIWBGtLLHIhWCmjgLJFB                                            Soranji
# 99  0aB0v4027ukVziUGwVGYpG                       tv off (feat. lefty gunplay)
#
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    object
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
song_df=song_df.drop_duplicates(subset='song_id') #This nothing really does because the songs are unique.

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   57GsLpRtEtrzcPGPop20rS                                   What Did I Miss?
# 1   48NthgcgfoRrWT8LtgW28A                     What I Want (feat. Tate McRae)
# 2   6qqrTXSdwiJaq8SO0X2lSe                                           Ordinary
# 3   0M7mWKqwTIaVjYyxfZmtTa  Courtesy Of The Red, White And Blue (The Angry...
# 4   47i9UVf2GnGcOgT51RXEw3                                       Just In Case
# ..                     ...                                                ...
# 95  35ISBknsCeZQtq66xABI9g                                              Messy
# 96  0MHStU0muAIEMbwdnebYu2                                           Takedown
# 97  4ZJ4vzLQekI0WntDbanNC7                                         Pink Skies
# 98  7qXIWBGtLLHIhWCmjgLJFB                                            Soranji
# 99  0aB0v4027ukVziUGwVGYpG                       tv off (feat. lefty gunplay)
#
# ...

# %%
song_df['song_added']= pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
